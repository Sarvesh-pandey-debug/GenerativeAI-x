# %% [markdown]
# ## Lets start with langchain and  OpenAI
#
# #### In the quickstart we will se how to:
#
# ###### - Get setup with langChain , LangSmith And  LangServe
#
# ###### - use the most basic and common components of LangChain: propmpt templaetes model and output parsers.
#
# ###### Build a simple application with Langchain
#
# ###### - Trace your application with LangSmith
#
# ###### - Serve your application with LangServe

# %%
# !pip install langchain-community
# Out:
# Requirement already satisfied: langchain-community in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langchain-community) (1.2.6)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langchain-community) (2.0.45)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langchain-community) (0.6.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langchain-community) (2.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.1)
# Requirement already satisfied: certifi in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.2)
# Requirement already satisfied: greenlet>=1 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\sarvesh\desktop\langchainframework\venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
